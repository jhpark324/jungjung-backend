# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("ASSEMBLY_API_KEY")

url = "https://open.assembly.go.kr/portal/openapi/nzbyfwhwaoanttzje"

params = {
    "KEY": API_KEY,
    "Type": "json",         
    "pIndex": 1,
    "pSize": 5,  
    "DAE_NUM": "22",
    "CONF_DATE": "2025-12"  
    # "ERESSION": "429",      # 회기
    # "CONFER_NUM": "14",     # 차수
}

# API 요청
response = requests.get(url, params=params)

# 응답 확인
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"에러: {response.status_code}")
    print(response.text)
# Out:
# {'nzbyfwhwaoanttzje': [{'head': [{'list_total_count': 160}, {'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'}}]}, {'row': [{'CONFER_NUM': 55982, 'TITLE': '제22대 제430회 제2차 국회본회의 (2025년 12월 22일)', 'CLASS_NAME': '국회본회의', 'DAE_NUM': 22, 'CONF_DATE': '2025-12-22', 'SUB_NAME': '1. 정치개혁 특별위원회 구성결의안(국회운영위원장 제출)(의안번호 2215375)', 'VOD_LINK_URL': 'http://w3.assembly.go.kr/main/player.do?menu=1&mc=10&ct1=22&ct2=430&ct3=02&wv=1', 'CONF_LINK_URL': 'https://record.assembly.go.kr/assembly/viewer/minutes/xml.do?id=55982&type=summary', 'PDF_LINK_URL': 'https://record.assembly.go.kr/assembly/viewer/minutes/download/pdf.do?id=55982', 'CONF_ID': 'N053892'}, {'CONFER_NUM': 55982, 'TITLE': '제22대 제430회 제2차 국회본회의 (2025년 12월 22일)', 'CLASS_NAME': '국회본회의', 'DAE_NUM': 22, 'CONF_DATE': '2025-12-22', 'SUB_NAME': '2. 12.29 여객기 참사 진상규명을 위한 국정조사계획서 승인의 건(12.29여객기참사진상규명을위한국정조사특별위원장 제출)(의안번호 2215464)', 'VOD_LINK_URL': 'http://w3.assembly.go.kr/main/player.do?menu=1&mc=10&ct1=22&ct2=430&ct3=02&wv=1', 'CONF_LINK_URL': 'https://record.assembly.go.kr/assembly/viewer/minutes/xml.do?id=55982&type=summary', 'PDF_LINK_URL': 'https://record.assembly.go.kr/assembly/viewer/minutes/download/pdf.do?id=55982', 'CONF_ID': 'N053892'}, {'CONFER_NUM': 55982, 'TITLE': '제22대 제430회 제2차 국회본회의 (2025년 12월 22일)', 'CLASS_NAME': '국회본회의', 'DAE_NUM': 22, 'CONF_DATE': '2025-12-22', 'SUB_NAME': '3. 12·3 윤석열 비상계엄 등에 대한 전담재판부 설치 및 제보자 보호 등에 관한 특별법안(대안)(법제사법위원장 제출)(의안번호 2214933)', 'VOD_LINK_URL': 'http://w3.assembly.go.kr/main/player.do?menu=1&mc=10&ct1=22&ct2=430&ct3=02&wv=1', 'CONF_LINK_URL': 'https://record.assembly.go.kr/assembly/viewer/minutes/xml.do?id=55982&type=summary', 'PDF_LINK_URL': 'https://record.assembly.go.kr/assembly/viewer/minutes/download/pdf.do?id=55982', 'CONF_ID': 'N053892'}, {'CONFER_NUM': 55982, 'TITLE': '제22대 제430회 제2차 국회본회의 (2025년 12월 22일)', 'CLASS_NAME': '국회본회의', 'DAE_NUM': 22, 'CONF_DATE': '2025-12-22', 'SUB_NAME': '- 무제한토론 의원(장동혁)', 'VOD_LINK_URL': 'http://w3.assembly.go.kr/main/player.do?menu=1&mc=10&ct1=22&ct2=430&ct3=02&wv=1', 'CONF_LINK_URL': 'https://record.assembly.go.kr/assembly/viewer/minutes/xml.do?id=55982&type=summary', 'PDF_LINK_URL': 'https://record.assembly.go.kr/assembly/viewer/minutes/download/pdf.do?id=55982', 'CONF_ID': 'N053892'}, {'CONFER_NUM': 55982, 'TITLE': '제22대 제430회 제2차 국회본회의 (2025년 12월 22일)', 'CLASS_NAME': '국회본회의', 'DAE_NUM': 22, 'CONF_DATE': '2025-12-22', 'SUB_NAME': 'o 무제한토론 종결동의의 건(허영 의원 등 166인 서면동의)', 'VOD_LINK_URL': 'http://w3.assembly.go.kr/main/player.do?menu=1&mc=10&ct1=22&ct2=430&ct3=02&wv=1', 'CONF_LINK_URL': 'https://record.assembly.go.kr/assembly/viewer/minutes/xml.do?id=55982&type=summary', 'PDF_LINK_URL': 'https://record.assembly.go.kr/assembly/viewer/minutes/download/pdf.do?id=55982', 'CONF_ID': 'N053892'}]}]}
